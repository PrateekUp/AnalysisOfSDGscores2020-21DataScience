# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\IIT\Projects\DataScienceproject\DSpro_sustainabledev_working\SDG 10.csv")

# %%
data.head()
# Out:
#    SNO Category         States_Uts  \
# 0    1    State     Andhra Pradesh
# 1    2    State  Arunachal Pradesh
# 2    3    State              Assam
# 3    4    State              Bihar
# 4    5    State       Chhattisgarh
#
#    Percentage_of_population_in_the_lowest_two_wealth_quintiles  \
# 0                                               22.4
# 1                                               43.6
# 2                                               62.5
# 3                                               75.2
# 4                                               59.0
#
#    Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha  \
# 0                                              16.00
# 1                                               0.00
# 2                                               7.14
# 3                                               7.50
# 4                                              27.27
#
# ...

# %%
data.isnull()
# Out:
#       SNO  Category  States_Uts  \
# 0   False     False       False
# 1   False     False       False
# 2   False     False       False
# 3   False     False       False
# 4   False     False       False
# 5   False     False       False
# 6   False     False       False
# 7   False     False       False
# 8   False     False       False
# 9   False     False       False
# 10  False     False       False
# 11  False     False       False
# 12  False     False       False
# 13  False     False       False
# 14  False     False       False
# 15  False     False       False
# 16  False     False       False
# 17  False     False       False
# 18  False     False       False
# 19  False     False       False
# 20  False     False       False
# 21  False     False       False
# 22  False     False       False
# 23  False     False       False
# 24  False     False       False
# 25  False     False       False
# 26  False     False       False
# 27  False     False       False
# ...

# %%
data.isnull()
# Out:
#       SNO  Category  States_Uts  \
# 0   False     False       False
# 1   False     False       False
# 2   False     False       False
# 3   False     False       False
# 4   False     False       False
# 5   False     False       False
# 6   False     False       False
# 7   False     False       False
# 8   False     False       False
# 9   False     False       False
# 10  False     False       False
# 11  False     False       False
# 12  False     False       False
# 13  False     False       False
# 14  False     False       False
# 15  False     False       False
# 16  False     False       False
# 17  False     False       False
# 18  False     False       False
# 19  False     False       False
# 20  False     False       False
# 21  False     False       False
# 22  False     False       False
# 23  False     False       False
# 24  False     False       False
# 25  False     False       False
# 26  False     False       False
# 27  False     False       False
# ...

# %%
data.head()
# Out:
#    SNO Category         States_Uts  \
# 0    1    State     Andhra Pradesh
# 1    2    State  Arunachal Pradesh
# 2    3    State              Assam
# 3    4    State              Bihar
# 4    5    State       Chhattisgarh
#
#    Percentage_of_population_in_the_lowest_two_wealth_quintiles  \
# 0                                               22.4
# 1                                               43.6
# 2                                               62.5
# 3                                               75.2
# 4                                               59.0
#
#    Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha  \
# 0                                              16.00
# 1                                               0.00
# 2                                               7.14
# 3                                               7.50
# 4                                              27.27
#
# ...

# %%
data
# Out:
#     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
data = pd.read_csv("D:\IIT\Projects\DataScienceproject\DSpro_sustainabledev_working\SDG 10.csv")

# %%
data.head()
# Out:
#    SNO Category         States_Uts  \
# 0    1    State     Andhra Pradesh
# 1    2    State  Arunachal Pradesh
# 2    3    State              Assam
# 3    4    State              Bihar
# 4    5    State       Chhattisgarh
#
#    Percentage_of_population_in_the_lowest_two_wealth_quintiles  \
# 0                                               22.4
# 1                                               43.6
# 2                                               62.5
# 3                                               75.2
# 4                                               59.0
#
#    Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha  \
# 0                                              16.00
# 1                                               0.00
# 2                                               7.14
# 3                                               7.50
# 4                                              27.27
#
# ...

# %%
data["Percentage_of_population_in_the_lowest_two_wealth_quintiles"].isnull().sum()
# Out:
# 0

# %%
data["Percentage_of_population_in_the_lowest_two_wealth_quintiles"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# Name: Percentage_of_population_in_the_lowest_two_wealth_quintiles, dtype: bool

# %%
data['Percentage_of_population_in_the_lowest_two_wealth_quintiles'].isnull().values.any()
# Out:
# False

# %%
data = pd.read_csv("D:\IIT\Projects\DataScienceproject\DSpro_sustainabledev_working\SDG 10.csv")

# %%
data.head()
# Out:
#    SNO Category         States_Uts  \
# 0    1    State     Andhra Pradesh
# 1    2    State  Arunachal Pradesh
# 2    3    State              Assam
# 3    4    State              Bihar
# 4    5    State       Chhattisgarh
#
#    Percentage_of_population_in_the_lowest_two_wealth_quintiles  \
# 0                                               22.4
# 1                                               43.6
# 2                                               62.5
# 3                                               75.2
# 4                                               59.0
#
#    Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha  \
# 0                                              16.00
# 1                                               0.00
# 2                                               7.14
# 3                                               7.50
# 4                                              27.27
#
# ...

# %%
data['Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions'].isnull().values.any()
# Out:
# True

# %%
data['Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions'].isnull().values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#         True])

# %%
data
# Out:
#     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
data
# Out:
#     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
a = data.shape

# %%
a
# Out:
# (37, 10)

# %%
data
# Out:
#     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States_Uts',
#        'Percentage_of_population_in_the_lowest_two_wealth_quintiles',
#        'Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha',
#        'Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions',
#        'Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies',
#        'Ratio_of_transgender_to_male_Labour_Force_Participation_Rate',
#        'Rate_of_total_crimes_against_SCs_per_100000_SC_population',
#        'Rate_of_total_crimes_against_STs_per_100000_ST_population'],
#       dtype='object')

# %%
sns.relplot(x="SNO", y="Ratio_of_transgender_to_male_Labour_Force_Participation_Rate", data=data)

# %%
sns.relplot(x="States_Uts", y="Ratio_of_transgender_to_male_Labour_Force_Participation_Rate", kind='line', data=data)

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States_Uts',
#        'Percentage_of_population_in_the_lowest_two_wealth_quintiles',
#        'Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha',
#        'Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions',
#        'Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies',
#        'Ratio_of_transgender_to_male_Labour_Force_Participation_Rate',
#        'Rate_of_total_crimes_against_SCs_per_100000_SC_population',
#        'Rate_of_total_crimes_against_STs_per_100000_ST_population'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States_Uts',
#        'Percentage_of_population_in_the_lowest_two_wealth_quintiles',
#        'Percentage_of_elected_women_over_total_seats_in_the_State/UT_Lok_Sabha',
#        'Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions',
#        'Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies',
#        'Ratio_of_transgender_to_male_Labour_Force_Participation_Rate',
#        'Rate_of_total_crimes_against_SCs_per_100000_SC_population',
#        'Rate_of_total_crimes_against_STs_per_100000_ST_population'],
#       dtype='object')

# %%
#code for histogtram for the SDGs 
#we have used similar codes for all SDGs
x=data['States_Uts']
y=data['Percentage_of_population_in_the_lowest_two_wealth_quintiles']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage_of_population_in_the_lowest_two_wealth_quintiles")
# Out:
# Text(0, 0.5, 'Percentage_of_population_in_the_lowest_two_wealth_quintiles')

# %%
data1 = data.dropna(subset=['Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions'])

# %%
data1
# Out:
#     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 16   17            State                      Mizoram
# ...

# %%
x=data1['States_Uts']
y=data1['Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)

plt.xlabel("States & UTs")
plt.ylabel("Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions")
# Out:
# Text(0, 0.5, 'Percentage_of_seats_held_by_women_in_Panchayati_Raj_Institutions')

# %%
data2 = data.dropna(subset=['Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies'])
data2
# Out:
#     SNO         Category         States_Uts  \
# 0     1            State     Andhra Pradesh
# 1     2            State  Arunachal Pradesh
# 2     3            State              Assam
# 3     4            State              Bihar
# 4     5            State       Chhattisgarh
# 5     6            State                Goa
# 6     7            State            Gujarat
# 7     8            State            Haryana
# 8     9            State   Himachal Pradesh
# 9    10            State          Jharkhand
# 10   11            State          Karnataka
# 11   12            State             Kerala
# 12   13            State     Madhya Pradesh
# 13   14            State        Maharashtra
# 14   15            State            Manipur
# 15   16            State          Meghalaya
# 16   17            State            Mizoram
# 17   18            State           Nagaland
# 18   19            State             Odisha
# 19   20            State             Punjab
# ...

# %%
x=data2['States_Uts']
y=data2['Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)

plt.xlabel("States & UTs")
plt.ylabel("Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies")
# Out:
# Text(0, 0.5, 'Percentage_of_SC/ST_seats_in_State_Legislative_Assemblies')

# %%
data3 = data.dropna(subset = ['Ratio_of_transgender_to_male_Labour_Force_Participation_Rate'])
data3
# Out:
#     SNO         Category         States_Uts  \
# 0     1            State     Andhra Pradesh
# 1     2            State  Arunachal Pradesh
# 2     3            State              Assam
# 3     4            State              Bihar
# 4     5            State       Chhattisgarh
# 6     7            State            Gujarat
# 7     8            State            Haryana
# 8     9            State   Himachal Pradesh
# 9    10            State          Jharkhand
# 10   11            State          Karnataka
# 11   12            State             Kerala
# 12   13            State     Madhya Pradesh
# 13   14            State        Maharashtra
# 15   16            State          Meghalaya
# 16   17            State            Mizoram
# 17   18            State           Nagaland
# 18   19            State             Odisha
# 19   20            State             Punjab
# 20   21            State          Rajasthan
# 21   22            State             Sikkim
# ...

# %%
x=data3['States_Uts']
y=data3['Ratio_of_transgender_to_male_Labour_Force_Participation_Rate']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)

plt.xlabel("States & UTs")
plt.ylabel("Ratio_of_transgender_to_male_Labour_Force_Participation_Rate")
# Out:
# Text(0, 0.5, 'Ratio_of_transgender_to_male_Labour_Force_Participation_Rate')

# %%
data4 = data.dropna(subset = ['Rate_of_total_crimes_against_SCs_per_100000_SC_population'])
data4
# Out:
#     SNO         Category              States_Uts  \
# 0     1            State          Andhra Pradesh
# 2     3            State                   Assam
# 3     4            State                   Bihar
# 4     5            State            Chhattisgarh
# 5     6            State                     Goa
# 6     7            State                 Gujarat
# 7     8            State                 Haryana
# 8     9            State        Himachal Pradesh
# 9    10            State               Jharkhand
# 10   11            State               Karnataka
# 11   12            State                  Kerala
# 12   13            State          Madhya Pradesh
# 13   14            State             Maharashtra
# 14   15            State                 Manipur
# 15   16            State               Meghalaya
# 16   17            State                 Mizoram
# 18   19            State                  Odisha
# 19   20            State                  Punjab
# ...

# %%
x=data4['States_Uts']
y=data4['Rate_of_total_crimes_against_SCs_per_100000_SC_population']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)

plt.xlabel("States & UTs")
plt.ylabel("Rate_of_total_crimes_against_SCs_per_100000_SC_population")
# Out:
# Text(0, 0.5, 'Rate_of_total_crimes_against_SCs_per_100000_SC_population')

# %%
data5 = data.dropna(subset = ['Rate_of_total_crimes_against_STs_per_100000_ST_population'])
data5
# Out:
#     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# 16   17            State                      Mizoram
# ...

# %%
x=data5['States_Uts']
y=data5['Rate_of_total_crimes_against_STs_per_100000_ST_population']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)

plt.xlabel("States & UTs")
plt.ylabel("Rate_of_total_crimes_against_STs_per_100000_ST_population")
# Out:
# Text(0, 0.5, 'Rate_of_total_crimes_against_STs_per_100000_ST_population')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     SNO         Category                   States_Uts  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...
