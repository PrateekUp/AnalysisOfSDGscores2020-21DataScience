# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("SDG1.csv")

# %%
df.head()
# Out:
#    SNO Category         States/UTs  \
# 0    1    State     Andhra Pradesh
# 1    2    State  Arunachal Pradesh
# 2    3    State              Assam
# 3    4    State              Bihar
# 4    5    State       Chhattisgarh
#
#    Percentage of population living below the national poverty line  \
# 0                                               9.20
# 1                                              34.67
# 2                                              31.98
# 3                                              33.74
# 4                                              39.93
#
#    Head count ratio as per the Multidimensional Poverty Index (%)  \
# 0                                               15.6
# 1                                               24.4
# 2                                               36.2
# 3                                               52.5
# 4                                               36.8
#
# ...

# %%
df.shape
# Out:
# (37, 14)

# %%
df.describe()
# Out:
#              SNO  \
# count  37.000000
# mean   19.000000
# std    10.824355
# min     1.000000
# 25%    10.000000
# 50%    19.000000
# 75%    28.000000
# max    37.000000
#
#        Percentage of population living below the national poverty line  \
# count                                          37.000000
# mean                                           17.762703
# std                                            11.730749
# min                                             0.000000
# 25%                                             9.690000
# 50%                                            14.050000
# 75%                                            29.430000
# max                                            39.930000
#
#        Head count ratio as per the Multidimensional Poverty Index (%)  \
# count                                          37.000000
# mean                                           19.524324
# std                                            13.976933
# ...

# %%
df.isnull()
# Out:
#       SNO  Category  States/UTs  \
# 0   False     False       False
# 1   False     False       False
# 2   False     False       False
# 3   False     False       False
# 4   False     False       False
# 5   False     False       False
# 6   False     False       False
# 7   False     False       False
# 8   False     False       False
# 9   False     False       False
# 10  False     False       False
# 11  False     False       False
# 12  False     False       False
# 13  False     False       False
# 14  False     False       False
# 15  False     False       False
# 16  False     False       False
# 17  False     False       False
# 18  False     False       False
# 19  False     False       False
# 20  False     False       False
# 21  False     False       False
# 22  False     False       False
# 23  False     False       False
# 24  False     False       False
# 25  False     False       False
# 26  False     False       False
# 27  False     False       False
# ...

# %%
df2=df.drop(df.index[37:41])

# %%
df2
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
fig=plt.figure()
ax= fig.add_axes([0,0,1,1])
xaxis=df2['SNO']
yaxis=df2['Percentage of population living below the national poverty line']
ax.bar(xaxis,yaxis)
plt.show()

# %%
df4=pd.read_csv("SDG2.csv")

# %%
fig=plt.figure()
ax= fig.add_axes([0,0,1,1])
xaxis=df4['SNO']
yaxis=df4['Percentage of population living below the national poverty line']
ax.bar(xaxis,yaxis)
plt.show()

# %%
fig=plt.figure()
ax= fig.add_axes([0,0,1,1])
xaxis=df4['SNO']
yaxis=df4['Percentage of the population (out of total eligible population) receiving social protection benefits under Pradhan Mantri Matru Vandana Yojana (PMMVY)']
ax.bar(xaxis,yaxis)
plt.show()
