# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("SDG3.csv")

# %%
df.head()
# Out:
#    SNO Category         States/UTs  \
# 0  1.0    State     Andhra Pradesh
# 1  2.0    State  Arunachal Pradesh
# 2  3.0    State              Assam
# 3  4.0    State              Bihar
# 4  5.0    State       Chhattisgarh
#
#   Maternal Mortality Ratio (per 1,00,000 live births)  \
# 0                                                 65
# 1                                               Null
# 2                                                215
# 3                                                149
# 4                                                159
#
#   Under 5 mortality rate (per 1,000 live births)   \
# 0                                              33
# 1                                            Null
# 2                                              47
# 3                                              37
# 4                                              45
#
#   Percentage of children in the age group 9-11 months fully immunized  \
# ...

# %%
df.shape
# Out:
# (41, 13)

# %%
df.describe()
# Out:
#              SNO
# count  37.000000
# mean   19.000000
# std    10.824355
# min     1.000000
# 25%    10.000000
# 50%    19.000000
# 75%    28.000000
# max    37.000000

# %%
df.isnull()
# Out:
#       SNO  Category  States/UTs  \
# 0   False     False       False
# 1   False     False       False
# 2   False     False       False
# 3   False     False       False
# 4   False     False       False
# 5   False     False       False
# 6   False     False       False
# 7   False     False       False
# 8   False     False       False
# 9   False     False       False
# 10  False     False       False
# 11  False     False       False
# 12  False     False       False
# 13  False     False       False
# 14  False     False       False
# 15  False     False       False
# 16  False     False       False
# 17  False     False       False
# 18  False     False       False
# 19  False     False       False
# 20  False     False       False
# 21  False     False       False
# 22  False     False       False
# 23  False     False       False
# 24  False     False       False
# 25  False     False       False
# 26  False     False       False
# 27  False     False       False
# ...

# %%
df2=df.drop(df.index[37:41])

# %%
df2
# Out:
#      SNO         Category                   States/UTs  \
# 0    1.0            State               Andhra Pradesh
# 1    2.0            State            Arunachal Pradesh
# 2    3.0            State                        Assam
# 3    4.0            State                        Bihar
# 4    5.0            State                 Chhattisgarh
# 5    6.0            State                          Goa
# 6    7.0            State                      Gujarat
# 7    8.0            State                      Haryana
# 8    9.0            State             Himachal Pradesh
# 9   10.0            State                    Jharkhand
# 10  11.0            State                    Karnataka
# 11  12.0            State                       Kerala
# 12  13.0            State               Madhya Pradesh
# 13  14.0            State                  Maharashtra
# 14  15.0            State                      Manipur
# 15  16.0            State                    Meghalaya
# ...

# %%
df2=df2.replace("Null"," ")

# %%
df2.index[df2['Maternal Mortality Ratio (per 1,00,000 live births)']==" "].tolist()
# Out:
# [1, 5, 8, 14, 15, 16, 17, 21, 24, 28, 29, 30, 31, 32, 33, 34, 35, 36]

# %%
df3=df2.drop(df2.index[1])

# %%
df3=df3.drop(df2.index[5])

# %%
df3=df3.drop(df2.index[8])

# %%
df3=df3.drop(df2.index[14])

# %%
df3=df3.drop(df2.index[15])

# %%
df3=df3.drop(df2.index[16])

# %%
df3=df3.drop(df2.index[17])

# %%
df3=df3.drop(df2.index[21])

# %%
df3=df3.drop(df2.index[24])

# %%
df3=df3.drop(df2.index[28:37])

# %%
df3
# Out:
#      SNO Category      States/UTs  \
# 0    1.0    State  Andhra Pradesh
# 2    3.0    State           Assam
# 3    4.0    State           Bihar
# 4    5.0    State    Chhattisgarh
# 6    7.0    State         Gujarat
# 7    8.0    State         Haryana
# 9   10.0    State       Jharkhand
# 10  11.0    State       Karnataka
# 11  12.0    State          Kerala
# 12  13.0    State  Madhya Pradesh
# 13  14.0    State     Maharashtra
# 18  19.0    State          Odisha
# 19  20.0    State          Punjab
# 20  21.0    State       Rajasthan
# 22  23.0    State      Tamil Nadu
# 23  24.0    State       Telangana
# 25  26.0    State   Uttar Pradesh
# 26  27.0    State     Uttarakhand
# 27  28.0    State     West Bengal
#
#    Maternal Mortality Ratio (per 1,00,000 live births)  \
# 0                                                  65
# 2                                                 215
# 3                                                 149
# ...

# %%
df3['Maternal Mortality Ratio (per 1,00,000 live births)'] = df3['Maternal Mortality Ratio (per 1,00,000 live births)'].astype(float)

# %%
df3['SNO'] = df3['SNO'].astype(str)

# %%
x = df3['SNO']
y = df3['Maternal Mortality Ratio (per 1,00,000 live births)'] 
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Maternal Mortality Ratio (per 1,00,000 live births)")
plt.xlabel("SNo of states")
plt.title("Maternal Mortality Ratio (per 1,00,000 live births)")
# Plot a simple line chart
plt.plot(x, y, 'b')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Under 5 mortality rate (per 1,000 live births) ']==" "].tolist()
# Out:
# [1, 5, 14, 15, 16, 17, 21, 24, 28, 29, 30, 31, 35, 36]

# %%
df4=df2.drop(df2.index[1])

# %%
df4=df4.drop(df2.index[5])

# %%
df4=df4.drop(df2.index[14:18])

# %%
df4=df4.drop(df2.index[21])

# %%
df4=df4.drop(df2.index[24])

# %%
df4=df4.drop(df2.index[28:32])

# %%
df4=df4.drop(df2.index[35:37])

# %%
df4['SNO'] = df4['SNO'].astype(str)

# %%
df4['Under 5 mortality rate (per 1,000 live births) '] = df4['Under 5 mortality rate (per 1,000 live births) '].astype(float)

# %%
x = df4['SNO']
y = df4['Under 5 mortality rate (per 1,000 live births) ']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Under 5 mortality rate (per 1,000 live births)")
plt.xlabel("SNo of states")
plt.title("Under 5 mortality rate (per 1,000 live births)")
# Plot a simple line chart
plt.plot(x, y, 'r')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Percentage of children in the age group 9-11 months fully immunized']==" "].tolist()
# Out:
# []

# %%
df2['Percentage of children in the age group 9-11 months fully immunized'] = df2['Percentage of children in the age group 9-11 months fully immunized'].astype(float)

# %%
df2['SNO'] = df2['SNO'].astype(str)

# %%
x = df2['SNO']
y = df2['Percentage of children in the age group 9-11 months fully immunized']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Percentage of children in the age group 9-11 months fully immunized")
plt.xlabel("SNo of states")
plt.title("Percentage of children in the age group 9-11 months fully immunized")
# Plot a simple line chart
plt.plot(x, y, 'y')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Total case notification rate of Tuberculosis per 1,00,000 population']==" "].tolist()
# Out:
# []

# %%
df2['Total case notification rate of Tuberculosis per 1,00,000 population'] = df2['Total case notification rate of Tuberculosis per 1,00,000 population'].astype(float)

# %%
df2['SNO'] = df2['SNO'].astype(str)

# %%
x = df2['SNO']
y = df2['Total case notification rate of Tuberculosis per 1,00,000 population'] 
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Total case notification rate of Tuberculosis per 1,00,000 population")
plt.xlabel("SNo of states")
plt.title("Total case notification rate of Tuberculosis per 1,00,000 population")
# Plot a simple line chart
plt.plot(x, y, 'g')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['HIV incidence per 1,000 uninfected population']==" "].tolist()
# Out:
# [35]

# %%
df5=df2.drop(df.index[35])

# %%
df5['HIV incidence per 1,000 uninfected population'] = df5['HIV incidence per 1,000 uninfected population'].astype(float)

# %%
df5['SNO']=df5['SNO'].astype(str)

# %%
x = df5['SNO']
y = df5['HIV incidence per 1,000 uninfected population']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("HIV incidence per 1,000 uninfected population")
plt.xlabel("SNo of states")
plt.title("HIV incidence per 1,000 uninfected population")
# Plot a simple line chart
plt.plot(x, y, 'black')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Suicide rate (per 1,00,000 population)']==" "].tolist()
# Out:
# []

# %%
df2['Suicide rate (per 1,00,000 population)'] = df2['Suicide rate (per 1,00,000 population)'].astype(float)

# %%
x = df2['SNO']
y = df2['Suicide rate (per 1,00,000 population)']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Suicide rate (per 1,00,000 population)")
plt.xlabel("SNo of states")
plt.title("Suicide rate (per 1,00,000 population)")
# Plot a simple line chart
plt.plot(x, y, 'pink')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Death rate due to road traffic accidents (per 1,00,000 population)']==" "].tolist()
# Out:
# []

# %%
df2['Death rate due to road traffic accidents (per 1,00,000 population)'] = df2['Death rate due to road traffic accidents (per 1,00,000 population)'].astype(float)

# %%
df2['SNO']=df2['SNO'].astype(str)

# %%
x = df2['SNO']
y = df2['Death rate due to road traffic accidents (per 1,00,000 population)']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Death rate due to road traffic accidents (per 1,00,000 population)")
plt.xlabel("SNo of states")
plt.title("Death rate due to road traffic accidents (per 1,00,000 population)")
# Plot a simple line chart
plt.plot(x, y, 'gold')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Percentage of institutional deliveries out of the total deliveries reported']==" "].tolist()
# Out:
# []

# %%
df2['Percentage of institutional deliveries out of the total deliveries reported'] = df2['Percentage of institutional deliveries out of the total deliveries reported'].astype(float)

# %%
df2['SNO']=df2['SNO'].astype(str)

# %%
x = df2['SNO']
y = df2['Percentage of institutional deliveries out of the total deliveries reported']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Percentage of institutional deliveries out of the total deliveries reported")
plt.xlabel("SNo of states")
plt.title("Percentage of institutional deliveries out of the total deliveries reported")
# Plot a simple line chart
plt.plot(x, y, 'brown')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)']==" "].tolist()
# Out:
# [21]

# %%
df6=df2.drop(df.index[21])

# %%
df6['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)'] = df6['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)'].astype(float)

# %%
df6['SNO']=df6['SNO'].astype(str)

# %%
x = df6['SNO']
y = df6['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)")
plt.xlabel("SNo of states")
plt.title("Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)")
# Plot a simple line chart
plt.plot(x, y, 'grey')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2.index[df2['Total physicians, nurses and midwives per 10,000 population']==" "].tolist()
# Out:
# [28, 30, 31, 35, 36]

# %%
df7=df2.drop(df2.index[28])

# %%
df7=df7.drop(df2.index[30:32])

# %%
df7=df7.drop(df2.index[35:37])

# %%
df7['Total physicians, nurses and midwives per 10,000 population'] = df7['Total physicians, nurses and midwives per 10,000 population'].astype(float)

# %%
df7['SNO']=df7['SNO'].astype(str)

# %%
x = df7['SNO']
y = df7['Total physicians, nurses and midwives per 10,000 population']
plt.rcParams["figure.figsize"] = [14.00, 10]

plt.ylabel("Total physicians, nurses and midwives per 10,000 population")
plt.xlabel("SNo of states")
plt.title("Total physicians, nurses and midwives per 10,000 population")
# Plot a simple line chart
plt.plot(x, y, 'purple')


plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
