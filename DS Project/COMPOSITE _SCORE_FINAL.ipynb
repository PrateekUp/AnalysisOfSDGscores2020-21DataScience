# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Composite Score.csv")

# %%
df.head()
# Out:
#   Category           State/UT  SDG 1  SDG 2  SDG 3  SDG 4  SDG 5  SDG 6  \
# 0    State     Andhra Pradesh     81     52     77     50     58     92
# 1    State  Arunachal Pradesh     54     66     64     41     37     67
# 2    State              Assam     51     41     59     43     25     64
# 3    State              Bihar     32     31     66     29     48     91
# 4    State       Chhattisgarh     49     37     60     55     64     89
#
#    SDG 7  SDG 8  SDG 9  SDG 10  SDG 11  SDG 12  SDG 13  SDG 15  SDG 16  \
# 0    100     67     52      74      78      84      63      69      77
# 1     85     50     31      69      39      77      58      93      64
# 2     98     50     39      65      55      66      53      78      62
# 3     78     50     24      48      67      59      16      62      73
# 4     78     64     36      72      78      64      38      65      71
#
#    Composite Score  Rank
# 0               72   4.0
# 1               60  22.0
# 2               57  26.0
# 3               52  28.0
# 4               61  19.0

# %%
df.shape
# Out:
# (38, 19)

# %%
df.describe()
# Out:
#             SDG 1       SDG 2       SDG 3       SDG 4       SDG 5       SDG 6  \
# count   38.000000   38.000000   38.000000   38.000000   38.000000   38.000000
# mean    67.210526   56.421053   72.605263   58.236842   51.368421   84.921053
# std     15.121415   17.701170    8.731860   13.672688   12.412768   10.667915
# min     32.000000   19.000000   59.000000   29.000000   25.000000   54.000000
# 25%     60.000000   44.250000   67.000000   49.000000   45.250000   83.000000
# 50%     69.000000   53.000000   72.000000   57.500000   50.500000   87.000000
# 75%     79.750000   68.250000   77.750000   64.000000   58.000000   90.750000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#             SDG 7       SDG 8       SDG 9      SDG 10      SDG 11      SDG 12  \
# count   38.000000   38.000000   38.000000   38.000000   38.000000   38.000000
# mean    92.526316   60.921053   49.684211   68.368421   73.131579   75.000000
# std     11.858939   10.957859   16.487678   12.449728   14.540105   13.217515
# min     50.000000   36.000000   23.000000   41.000000   39.000000   47.000000
# 25%     85.250000   54.750000   37.000000   65.000000   65.000000   66.000000
# 50%    100.000000   60.500000   47.500000   67.500000   76.500000   76.500000
# 75%    100.000000   65.750000   60.750000   73.500000   81.000000   82.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#            SDG 13     SDG 15      SDG 16  Composite Score       Rank
# count   38.000000   38.00000   38.000000        38.000000  36.000000
# mean    54.526316   65.50000   73.342105        66.947368  11.638889
# std     16.726313   14.45543    8.936038         8.009951   8.394395
# min     16.000000   27.00000   46.000000        52.000000   1.000000
# 25%     45.250000   59.25000   70.250000        61.250000   4.000000
# 50%     58.000000   64.50000   73.000000        67.000000  10.000000
# 75%     64.500000   72.75000   78.500000        70.750000  19.000000
# max    100.000000  100.00000  100.000000       100.000000  28.000000

# %%
df.isnull()
# Out:
#     Category  State/UT  SDG 1  SDG 2  SDG 3  SDG 4  SDG 5  SDG 6  SDG 7  \
# 0      False     False  False  False  False  False  False  False  False
# 1      False     False  False  False  False  False  False  False  False
# 2      False     False  False  False  False  False  False  False  False
# 3      False     False  False  False  False  False  False  False  False
# 4      False     False  False  False  False  False  False  False  False
# 5      False     False  False  False  False  False  False  False  False
# 6      False     False  False  False  False  False  False  False  False
# 7      False     False  False  False  False  False  False  False  False
# 8      False     False  False  False  False  False  False  False  False
# 9      False     False  False  False  False  False  False  False  False
# 10     False     False  False  False  False  False  False  False  False
# 11     False     False  False  False  False  False  False  False  False
# 12     False     False  False  False  False  False  False  False  False
# 13     False     False  False  False  False  False  False  False  False
# 14     False     False  False  False  False  False  False  False  False
# 15     False     False  False  False  False  False  False  False  False
# 16     False     False  False  False  False  False  False  False  False
# 17     False     False  False  False  False  False  False  False  False
# 18     False     False  False  False  False  False  False  False  False
# 19     False     False  False  False  False  False  False  False  False
# 20     False     False  False  False  False  False  False  False  False
# 21     False     False  False  False  False  False  False  False  False
# 22     False     False  False  False  False  False  False  False  False
# 23     False     False  False  False  False  False  False  False  False
# 24     False     False  False  False  False  False  False  False  False
# 25     False     False  False  False  False  False  False  False  False
# 26     False     False  False  False  False  False  False  False  False
# 27     False     False  False  False  False  False  False  False  False
# 28     False     False  False  False  False  False  False  False  False
# 29     False     False  False  False  False  False  False  False  False
# 30     False     False  False  False  False  False  False  False  False
# 31     False     False  False  False  False  False  False  False  False
# 32     False     False  False  False  False  False  False  False  False
# 33     False     False  False  False  False  False  False  False  False
# 34     False     False  False  False  False  False  False  False  False
# 35     False     False  False  False  False  False  False  False  False
# 36      True     False  False  False  False  False  False  False  False
# 37      True     False  False  False  False  False  False  False  False
#
#     SDG 8  SDG 9  SDG 10  SDG 11  SDG 12  SDG 13  SDG 15  SDG 16  \
# 0   False  False   False   False   False   False   False   False
# 1   False  False   False   False   False   False   False   False
# 2   False  False   False   False   False   False   False   False
# 3   False  False   False   False   False   False   False   False
# 4   False  False   False   False   False   False   False   False
# 5   False  False   False   False   False   False   False   False
# 6   False  False   False   False   False   False   False   False
# 7   False  False   False   False   False   False   False   False
# 8   False  False   False   False   False   False   False   False
# 9   False  False   False   False   False   False   False   False
# 10  False  False   False   False   False   False   False   False
# 11  False  False   False   False   False   False   False   False
# 12  False  False   False   False   False   False   False   False
# 13  False  False   False   False   False   False   False   False
# 14  False  False   False   False   False   False   False   False
# 15  False  False   False   False   False   False   False   False
# 16  False  False   False   False   False   False   False   False
# 17  False  False   False   False   False   False   False   False
# 18  False  False   False   False   False   False   False   False
# 19  False  False   False   False   False   False   False   False
# 20  False  False   False   False   False   False   False   False
# 21  False  False   False   False   False   False   False   False
# 22  False  False   False   False   False   False   False   False
# 23  False  False   False   False   False   False   False   False
# 24  False  False   False   False   False   False   False   False
# 25  False  False   False   False   False   False   False   False
# 26  False  False   False   False   False   False   False   False
# 27  False  False   False   False   False   False   False   False
# 28  False  False   False   False   False   False   False   False
# 29  False  False   False   False   False   False   False   False
# 30  False  False   False   False   False   False   False   False
# 31  False  False   False   False   False   False   False   False
# 32  False  False   False   False   False   False   False   False
# 33  False  False   False   False   False   False   False   False
# 34  False  False   False   False   False   False   False   False
# 35  False  False   False   False   False   False   False   False
# 36  False  False   False   False   False   False   False   False
# 37  False  False   False   False   False   False   False   False
#
#     Composite Score   Rank
# 0             False  False
# 1             False  False
# 2             False  False
# 3             False  False
# 4             False  False
# 5             False  False
# 6             False  False
# 7             False  False
# 8             False  False
# 9             False  False
# 10            False  False
# 11            False  False
# 12            False  False
# 13            False  False
# 14            False  False
# 15            False  False
# 16            False  False
# 17            False  False
# 18            False  False
# 19            False  False
# 20            False  False
# 21            False  False
# 22            False  False
# 23            False  False
# 24            False  False
# 25            False  False
# 26            False  False
# 27            False  False
# 28            False  False
# 29            False  False
# 30            False  False
# 31            False  False
# 32            False  False
# 33            False  False
# 34            False  False
# 35            False  False
# 36            False   True
# 37            False   True

# %%
df2=df.drop(df.index[36:38])

# %%
df2
# Out:
#            Category                                  State/UT  SDG 1  SDG 2  \
# 0             State                            Andhra Pradesh     81     52
# 1             State                         Arunachal Pradesh     54     66
# 2             State                                     Assam     51     41
# 3             State                                     Bihar     32     31
# 4             State                              Chhattisgarh     49     37
# 5             State                                       Goa     83     78
# 6             State                                   Gujarat     66     46
# 7             State                                   Haryana     69     58
# 8             State                          Himachal Pradesh     80     52
# 9             State                                 Jharkhand     36     19
# 10            State                                 Karnataka     68     53
# 11            State                                    Kerala     83     80
# 12            State                            Madhya Pradesh     44     43
# 13            State                               Maharashtra     66     44
# 14            State                                   Manipur     60     64
# 15            State                                 Meghalaya     77     37
# 16            State                                   Mizoram     80     72
# 17            State                                  Nagaland     73     64
# 18            State                                    Odisha     41     42
# 19            State                                    Punjab     69     73
# 20            State                                 Rajasthan     63     53
# 21            State                                    Sikkim     80     69
# 22            State                                Tamil Nadu     86     66
# 23            State                                 Telangana     68     50
# 24            State                                   Tripura     82     52
# 25            State                             Uttar Pradesh     44     41
# 26            State                               Uttarakhand     74     61
# 27            State                               West Bengal     59     46
# 28  Union Territory               Andaman and Nicobar Islands     71     45
# 29  Union Territory                                Chandigarh     75     97
# 30  Union Territory  Dadra and Nagar Haveli and Daman and Diu     65     27
# 31  Union Territory                                     Delhi     81     63
# 32  Union Territory                         Jammu and Kashmir     69     71
# 33  Union Territory                                   Ladakh      79     71
# 34  Union Territory                               Lakshadweep     61     74
# 35  Union Territory                                Puducherry     75     59
#
#     SDG 3  SDG 4  SDG 5  SDG 6  SDG 7  SDG 8  SDG 9  SDG 10  SDG 11  SDG 12  \
# 0      77     50     58     92    100     67     52      74      78      84
# 1      64     41     37     67     85     50     31      69      39      77
# 2      59     43     25     64     98     50     39      65      55      66
# 3      66     29     48     91     78     50     24      48      67      59
# 4      60     55     64     89     78     64     36      72      78      64
# 5      72     71     55    100    100     76     68      75      89      47
# 6      86     52     49     93     94     64     72      64      87      50
# 7      72     64     43     80    100     59     66      68      81      77
# 8      78     74     62     85    100     78     61      78      79      77
# 9      74     45     51     83     77     54     37      65      71      55
# 10     78     64     57     85    100     66     64      67      78      89
# 11     72     80     63     89    100     62     60      69      75      65
# 12     62     45     55     88     86     60     37      51      81      78
# 13     83     64     51     90    100     62     66      71      87      82
# 14     68     63     41     87     96     36     35      70      65      89
# 15     70     48     51     75     50     63     25      88      51      73
# 16     79     60     54     85    100     51     32      64      61      87
# 17     61     39     48     87     69     48     30      46      48      91
# 18     67     45     46     86     80     48     46      66      70      73
# 19     77     60     45     66    100     57     69      68      91      71
# 20     70     60     39     54    100     57     45      45      81      74
# 21     62     58     58     89    100     71     52      61      85      76
# 22     81     69     59     87    100     71     71      74      79      78
# 23     67     63     41     96    100     73     59      67      76      73
# 24     67     42     39     82     83     57     35      85      67      99
# 25     60     51     50     83    100     53     42      41      77      79
# 26     77     70     46     85    100     63     56      77      76      82
# 27     76     54     41     81     98     57     53      71      45      79
# 28     68     57     68     87    100     59     23      67      85      73
# 29     74     79     58     99    100     70     45     100      98      78
# 30     80     56     53     95     71     57     47      66      89      62
# 31     90     75     33     61    100     65     66      72      65      50
# 32     70     49     46     88    100     47     42      65      57      95
# 33     70     49     46     84    100     59     48      65      57      95
# 34     78     62     58    100     83     62     40      75      56      63
# 35     70     70     66     91     98     68     59      62      76      66
#
#     SDG 13  SDG 15  SDG 16  Composite Score  Rank
# 0       63      69      77               72   4.0
# 1       58      93      64               60  22.0
# 2       53      78      62               57  26.0
# 3       16      62      73               52  28.0
# 4       38      65      71               61  19.0
# 5       44      59      63               72   4.0
# 6       67      61      82               69  10.0
# 7       51      48      71               67  14.0
# 8       62      68      73               74   2.0
# 9       25      71      70               56  27.0
# 10      62      67      76               72   4.0
# 11      69      77      80               75   1.0
# 12      49      84      66               62  17.0
# 13      58      52      69               70   9.0
# 14      57      60      69               64  16.0
# 15      62      64      72               60  22.0
# 16      66      48      81               68  12.0
# 17      69      63      79               61  19.0
# 18      70      83      59               61  19.0
# 19      51      48      76               68  12.0
# 20      49      43      73               60  22.0
# 21      65      73      72               71   8.0
# 22      61      63      71               74   2.0
# 23      43      81      71               69  10.0
# 24      41      69      80               65  15.0
# 25      39      61      79               60  22.0
# 26      60      64      86               72   4.0
# 27      39      53      81               62  17.0
# 28      77      72      46               67   5.0
# 29      61      85      73               79   1.0
# 30      18      62      75               62   8.0
# 31      55      81      62               68   2.0
# 32      63      52      74               66   6.0
# 33      66      27      74               66   6.0
# 34      68      67      77               68   2.0
# 35      23      50      86               68   2.0

# %%
df2=df2.replace("Null"," ")

# %%
df2.index[df2['SDG 1']==" "].tolist()
# Out:
# []

# %%
df3=df2.drop(df2.index[1])

# %%
df3=df3.drop(df2.index[5])

# %%
df3=df3.drop(df2.index[8])

# %%
df3=df3.drop(df2.index[14])

# %%
df3=df3.drop(df2.index[15])

# %%
df3=df3.drop(df2.index[16])

# %%
df3=df3.drop(df2.index[17])

# %%
df3=df3.drop(df2.index[21])

# %%
df3=df3.drop(df2.index[24])

# %%
df3=df3.drop(df2.index[28:37])

# %%
df3
# Out:
#      SNO Category      States/UTs  \
# 0    1.0    State  Andhra Pradesh
# 2    3.0    State           Assam
# 3    4.0    State           Bihar
# 4    5.0    State    Chhattisgarh
# 6    7.0    State         Gujarat
# 7    8.0    State         Haryana
# 9   10.0    State       Jharkhand
# 10  11.0    State       Karnataka
# 11  12.0    State          Kerala
# 12  13.0    State  Madhya Pradesh
# 13  14.0    State     Maharashtra
# 18  19.0    State          Odisha
# 19  20.0    State          Punjab
# 20  21.0    State       Rajasthan
# 22  23.0    State      Tamil Nadu
# 23  24.0    State       Telangana
# 25  26.0    State   Uttar Pradesh
# 26  27.0    State     Uttarakhand
# 27  28.0    State     West Bengal
#
#    Maternal Mortality Ratio (per 1,00,000 live births)  \
# 0                                                  65
# 2                                                 215
# 3                                                 149
# 4                                                 159
# 6                                                  75
# 7                                                  91
# 9                                                  71
# 10                                                 92
# 11                                                 43
# 12                                                173
# 13                                                 46
# 18                                                150
# 19                                                129
# 20                                                164
# 22                                                 60
# 23                                                 63
# 25                                                197
# 26                                                 99
# 27                                                 98
#
#    Under 5 mortality rate (per 1,000 live births)   \
# 0                                               33
# 2                                               47
# 3                                               37
# 4                                               45
# 6                                               31
# 7                                               36
# 9                                               34
# 10                                              28
# 11                                              10
# 12                                              56
# 13                                              22
# 18                                              44
# 19                                              23
# 20                                              40
# 22                                              17
# 23                                              30
# 25                                              47
# 26                                              33
# 27                                              26
#
#    Percentage of children in the age group 9-11 months fully immunized  \
# 0                                                  87
# 2                                                  85
# 3                                                  94
# 4                                                  95
# 6                                                  87
# 7                                                  87
# 9                                                  94
# 10                                                 94
# 11                                                 92
# 12                                                 89
# 13                                                100
# 18                                                 88
# 19                                                 89
# 20                                                 69
# 22                                                 84
# 23                                                 98
# 25                                                 95
# 26                                                 90
# 27                                                 97
#
#    Total case notification rate of Tuberculosis per 1,00,000 population  \
# 0                                                 189
# 2                                                 141
# 3                                                 100
# 4                                                 148
# 6                                                 232
# 7                                                 255
# 9                                                 146
# 10                                                135
# 11                                                 75
# 12                                                226
# 13                                                183
# 18                                                117
# 19                                                196
# 20                                                223
# 22                                                138
# 23                                                192
# 25                                                213
# 26                                                227
# 27                                                111
#
#    HIV incidence per 1,000 uninfected population  \
# 0                                           0.05
# 2                                           0.04
# 3                                           0.07
# 4                                            0.1
# 6                                           0.05
# 7                                           0.09
# 9                                           0.04
# 10                                          0.02
# 11                                          0.02
# 12                                          0.04
# 13                                          0.07
# 18                                          0.05
# 19                                          0.08
# 20                                          0.04
# 22                                          0.04
# 23                                          0.08
# 25                                          0.03
# 26                                          0.04
# 27                                          0.04
#
#    Suicide rate (per 1,00,000 population)  \
# 0                                    12.4
# 2                                     6.9
# 3                                     0.5
# 4                                    26.4
# 6                                    11.2
# 7                                    14.5
# 9                                     4.4
# 10                                   17.1
# 11                                   24.3
# 12                                   15.1
# 13                                   15.4
# 18                                   10.5
# 19                                    7.9
# 20                                    5.8
# 22                                   17.8
# 23                                   20.6
# 25                                    2.4
# 26                                    4.6
# 27                                     13
#
#    Death rate due to road traffic accidents (per 1,00,000 population)  \
# 0                                  15.261397304788304
# 2                                   9.428206171189494
# 3                                   5.998468121950813
# 4                                  17.340219048939417
# 6                                  10.884313869147922
# 7                                  18.290693234283335
# 9                                  10.114153428594237
# 10                                 16.599214830309368
# 11                                  12.41971238560791
# 12                                 14.351252224226211
# 13                                  11.92168640284658
# 18                                 11.819854163434474
# 19                                  15.40799625906009
# 20                                 13.611937990489812
# 22                                 13.882843311833064
# 23                                 18.678754392082183
# 25                                 10.304601999406993
# 26                                  7.752145922746781
# 27                                  5.894407315490841
#
#    Percentage of institutional deliveries out of the total deliveries reported  \
# 0                                                99.6
# 2                                                91.1
# 3                                                84.8
# 4                                                98.3
# 6                                                99.5
# 7                                                95.7
# 9                                                95.8
# 10                                               99.9
# 11                                               99.9
# 12                                               95.6
# 13                                               99.3
# 18                                               97.2
# 19                                               98.5
# 20                                               98.2
# 22                                               99.9
# 23                                               99.9
# 25                                               87.6
# 26                                               88.8
# 27                                               98.6
#
#    Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)  \
# 0                                                13.5
# 2                                                12.9
# 3                                                14.5
# 4                                                 6.6
# 6                                                 9.5
# 7                                                10.4
# 9                                                  11
# 10                                                9.8
# 11                                                 17
# 12                                               12.2
# 13                                               14.5
# 18                                               13.1
# 19                                               13.5
# 20                                               11.8
# 22                                                9.1
# 23                                               14.4
# 25                                               16.6
# 26                                               12.5
# 27                                               16.9
#
#    Total physicians, nurses and midwives per 10,000 population
# 0                                    95.1438675143481
# 2                                   22.57158132351194
# 3                                  16.788101346191795
# 4                                  14.717632815838199
# 6                                   41.19425240612715
# 7                                   26.27625375053579
# 9                                  3.9384312007011397
# 10                                  70.20423251085852
# 11                                 115.00071795755434
# 12                                 32.836709034097275
# 13                                  43.08434997380436
# 18                                  39.43864229765013
# 19                                  56.32892057026477
# 20                                  49.12018416596105
# 22                                  65.46520917103827
# 23                                 10.339605198760129
# 25                                 13.548416417089697
# 26                                 15.083737530886795
# 27                                  26.71814873137208

# %%
df3['Maternal Mortality Ratio (per 1,00,000 live births)'] = df3['Maternal Mortality Ratio (per 1,00,000 live births)'].astype(float)

# %%
df3['SNO'] = df3['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,2])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['State/UT']
yaxis=df2['SDG 1']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Score of States",fontsize=15)
plt.xticks(rotation=90)

plt.title("Score of SDG1 for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="blue",width=0.6)
plt.show()

# %%
df2.index[df2['SDG 2']==" "].tolist()
# Out:
# []

# %%
df4=df2.drop(df2.index[1])

# %%
df4=df4.drop(df2.index[5])

# %%
df4=df4.drop(df2.index[14:18])

# %%
df4=df4.drop(df2.index[21])

# %%
df4=df4.drop(df2.index[24])

# %%
df4=df4.drop(df2.index[28:32])

# %%
df4=df4.drop(df2.index[35:37])

# %%
df4['SNO'] = df4['SNO'].astype(str)

# %%
df4['Under 5 mortality rate (per 1,000 live births) '] = df4['Under 5 mortality rate (per 1,000 live births) '].astype(float)

# %%
fig=plt.figure(figsize=[5,2])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['State/UT']
yaxis=df2['SDG 2']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Score of States ",fontsize=15)
plt.xticks(rotation=90)

plt.title("Score of SDG2 for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="red",width=0.6)
plt.show()

# %%
df2.index[df2['SDG 3']==" "].tolist()
# Out:
# []

# %%
df2['Percentage of children in the age group 9-11 months fully immunized'] = df2['Percentage of children in the age group 9-11 months fully immunized'].astype(float)

# %%
df2['SNO'] = df2['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,2])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['State/UT']
yaxis=df2['SDG 3']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Score of different States",fontsize=10)
plt.xticks(rotation=90)

plt.title("Score for SDG3 for different states",fontsize=20)
ax.bar(xaxis,yaxis,color="gold",width=0.6)
plt.show()

# %%
df2.index[df2['Total case notification rate of Tuberculosis per 1,00,000 population']==" "].tolist()
# Out:
# []

# %%
df2['Total case notification rate of Tuberculosis per 1,00,000 population'] = df2['Total case notification rate of Tuberculosis per 1,00,000 population'].astype(float)

# %%
df2['SNO'] = df2['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,3])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['States/UTs']
yaxis=df2['Total case notification rate of Tuberculosis per 1,00,000 population']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Total case notification rate of Tuberculosis per 1,00,000 population",fontsize=8)
plt.xticks(rotation=90)

plt.title("Total case notification rate of Tuberculosis per 1,00,000 population for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="green",width=0.6)
plt.show()

# %%
df2.index[df2['HIV incidence per 1,000 uninfected population']==" "].tolist()
# Out:
# [35]

# %%
df5=df2.drop(df.index[35])

# %%
df5['HIV incidence per 1,000 uninfected population'] = df5['HIV incidence per 1,000 uninfected population'].astype(float)

# %%
df5['SNO']=df5['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,3])
ax= fig.add_axes([0,0,3,3])
xaxis=df5['States/UTs']
yaxis=df5['HIV incidence per 1,000 uninfected population']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("HIV incidence per 1,000 uninfected population",fontsize=9)
plt.xticks(rotation=90)

plt.title("HIV incidence per 1,000 uninfected population for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="black",width=0.6)
plt.show()

# %%
df2.index[df2['Suicide rate (per 1,00,000 population)']==" "].tolist()
# Out:
# []

# %%
df2['Suicide rate (per 1,00,000 population)'] = df2['Suicide rate (per 1,00,000 population)'].astype(float)

# %%
fig=plt.figure(figsize=[5,2])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['States/UTs']
yaxis=df2['Suicide rate (per 1,00,000 population)']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Suicide rate (per 1,00,000 population)",fontsize=15)
plt.xticks(rotation=90)

plt.title("Suicide rate (per 1,00,000 population) for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="pink",width=0.6)
plt.show()

# %%
df2.index[df2['Death rate due to road traffic accidents (per 1,00,000 population)']==" "].tolist()
# Out:
# []

# %%
df2['Death rate due to road traffic accidents (per 1,00,000 population)'] = df2['Death rate due to road traffic accidents (per 1,00,000 population)'].astype(float)

# %%
df2['SNO']=df2['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,3])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['States/UTs']
yaxis=df2['Death rate due to road traffic accidents (per 1,00,000 population)']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Death rate due to road traffic accidents (per 1,00,000 population)",fontsize=9)
plt.xticks(rotation=90)

plt.title("Death rate due to road traffic accidents (per 1,00,000 population) for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="orange",width=0.6)
plt.show()

# %%
df2.index[df2['Percentage of institutional deliveries out of the total deliveries reported']==" "].tolist()
# Out:
# []

# %%
df2['Percentage of institutional deliveries out of the total deliveries reported'] = df2['Percentage of institutional deliveries out of the total deliveries reported'].astype(float)

# %%
df2['SNO']=df2['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,3])
ax= fig.add_axes([0,0,3,3])
xaxis=df2['States/UTs']
yaxis=df2['Percentage of institutional deliveries out of the total deliveries reported']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Percentage of institutional deliveries out of the total deliveries reported",fontsize=9)
plt.xticks(rotation=90)

plt.title("Percentage of institutional deliveries out of the total deliveries reported for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="brown",width=0.6)
plt.show()

# %%
df2.index[df2['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)']==" "].tolist()
# Out:
# [21]

# %%
df6=df2.drop(df.index[21])

# %%
df6['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)'] = df6['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)'].astype(float)

# %%
df6['SNO']=df6['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,3])
ax= fig.add_axes([0,0,3,3])
xaxis=df6['States/UTs']
yaxis=df6['Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE)",fontsize=9)
plt.xticks(rotation=90)

plt.title("Monthly per capita out-of-pocket expenditure on health as a share of Monthly Per capita Consumption Expenditure (MPCE) for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="grey",width=0.6)
plt.show()

# %%
df2.index[df2['Total physicians, nurses and midwives per 10,000 population']==" "].tolist()
# Out:
# [28, 30, 31, 35, 36]

# %%
df7=df2.drop(df2.index[28])

# %%
df7=df7.drop(df2.index[30:32])

# %%
df7=df7.drop(df2.index[35:37])

# %%
df7['Total physicians, nurses and midwives per 10,000 population'] = df7['Total physicians, nurses and midwives per 10,000 population'].astype(float)

# %%
df7['SNO']=df7['SNO'].astype(str)

# %%
fig=plt.figure(figsize=[5,3])
ax= fig.add_axes([0,0,3,3])
xaxis=df7['States/UTs']
yaxis=df7['Total physicians, nurses and midwives per 10,000 population']
plt.xlabel("State/UT Name",fontsize=15)
plt.ylabel("Total physicians, nurses and midwives per 10,000 population",fontsize=9)
plt.xticks(rotation=90)

plt.title("Total physicians, nurses and midwives per 10,000 population for different States/UTs ",fontsize=20)
ax.bar(xaxis,yaxis,color="purple",width=0.6)
plt.show()
