# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\IIT\Projects\DataScienceproject\DSpro_sustainabledev_working\SDG 11.csv")

# %%
data
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States/UTs',
#        'Percentage of urban households living in katcha houses',
#        'Deaths due to road accidents in urban areas (per 1,00,000 population) ',
#        'Percentage of wards with 100% door to door waste collection (SBM(U))',
#        'Percentage of individual household toilets constructed against target (SBM(U))',
#        'Percentage of  MSW processed to the total MSW generated (SBM(U))',
#        'Percentage of wards with 100% source segregation (SBM(U))',
#        'Installed sewage treatment capacity as a percentage of sewage generated in urban areas ',
#        'Percentage of urban households with drainage facility'],
#       dtype='object')

# %%
x=data['States/UTs']
y=data['Percentage of urban households living in katcha houses']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage of urban households living in katcha houses")
# Out:
# Text(0, 0.5, 'Percentage of urban households living in katcha houses')

# %%
x=data['States/UTs']
y=data['Deaths due to road accidents in urban areas (per 1,00,000 population) ']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Deaths due to road accidents in urban areas (per 1,00,000 population) ")
# Out:
# Text(0, 0.5, 'Deaths due to road accidents in urban areas (per 1,00,000 population) ')

# %%
data1= data.dropna(subset=['Percentage of wards with 100% door to door waste collection (SBM(U))'])

# %%
data1
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
x=data1['States/UTs']
y=data1['Percentage of wards with 100% door to door waste collection (SBM(U))']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage of wards with 100% door to door waste collection (SBM(U))")
# Out:
# Text(0, 0.5, 'Percentage of wards with 100% door to door waste collection (SBM(U))')

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States/UTs',
#        'Percentage of urban households living in katcha houses',
#        'Deaths due to road accidents in urban areas (per 1,00,000 population) ',
#        'Percentage of wards with 100% door to door waste collection (SBM(U))',
#        'Percentage of individual household toilets constructed against target (SBM(U))',
#        'Percentage of  MSW processed to the total MSW generated (SBM(U))',
#        'Percentage of wards with 100% source segregation (SBM(U))',
#        'Installed sewage treatment capacity as a percentage of sewage generated in urban areas ',
#        'Percentage of urban households with drainage facility'],
#       dtype='object')

# %%
data2= data.dropna(subset=['Percentage of individual household toilets constructed against target (SBM(U))'])
data2
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
x=data2['States/UTs']
y=data2['Percentage of individual household toilets constructed against target (SBM(U))']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage of individual household toilets constructed against target (SBM(U))")
# Out:
# Text(0, 0.5, 'Percentage of individual household toilets constructed against target (SBM(U))')

# %%
data3= data.dropna(subset=['Percentage of  MSW processed to the total MSW generated (SBM(U))'])
data3
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
x=data3['States/UTs']
y=data3['Percentage of  MSW processed to the total MSW generated (SBM(U))']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage of  MSW processed to the total MSW generated (SBM(U))")
# Out:
# Text(0, 0.5, 'Percentage of  MSW processed to the total MSW generated (SBM(U))')

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States/UTs',
#        'Percentage of urban households living in katcha houses',
#        'Deaths due to road accidents in urban areas (per 1,00,000 population) ',
#        'Percentage of wards with 100% door to door waste collection (SBM(U))',
#        'Percentage of individual household toilets constructed against target (SBM(U))',
#        'Percentage of  MSW processed to the total MSW generated (SBM(U))',
#        'Percentage of wards with 100% source segregation (SBM(U))',
#        'Installed sewage treatment capacity as a percentage of sewage generated in urban areas ',
#        'Percentage of urban households with drainage facility'],
#       dtype='object')

# %%
data4= data.dropna(subset=['Percentage of wards with 100% source segregation (SBM(U))'])
data4
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
x=data4['States/UTs']
y=data4['Percentage of wards with 100% source segregation (SBM(U))']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage of wards with 100% source segregation (SBM(U))")
# Out:
# Text(0, 0.5, 'Percentage of wards with 100% source segregation (SBM(U))')

# %%
data.columns
# Out:
# Index(['SNO', 'Category', 'States/UTs',
#        'Percentage of urban households living in katcha houses',
#        'Deaths due to road accidents in urban areas (per 1,00,000 population) ',
#        'Percentage of wards with 100% door to door waste collection (SBM(U))',
#        'Percentage of individual household toilets constructed against target (SBM(U))',
#        'Percentage of  MSW processed to the total MSW generated (SBM(U))',
#        'Percentage of wards with 100% source segregation (SBM(U))',
#        'Installed sewage treatment capacity as a percentage of sewage generated in urban areas ',
#        'Percentage of urban households with drainage facility'],
#       dtype='object')

# %%
data5= data.dropna(subset=['Installed sewage treatment capacity as a percentage of sewage generated in urban areas '])
data5
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
x=data5['States/UTs']
y=data5['Installed sewage treatment capacity as a percentage of sewage generated in urban areas ']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Installed sewage treatment capacity as a percentage of sewage generated in urban areas ")
# Out:
# Text(0, 0.5, 'Installed sewage treatment capacity as a percentage of sewage generated in urban areas ')

# %%
data6= data.dropna(subset=['Percentage of urban households with drainage facility'])
data6
# Out:
#     SNO         Category                   States/UTs  \
# 0     1            State               Andhra Pradesh
# 1     2            State            Arunachal Pradesh
# 2     3            State                        Assam
# 3     4            State                        Bihar
# 4     5            State                 Chhattisgarh
# 5     6            State                          Goa
# 6     7            State                      Gujarat
# 7     8            State                      Haryana
# 8     9            State             Himachal Pradesh
# 9    10            State                    Jharkhand
# 10   11            State                    Karnataka
# 11   12            State                       Kerala
# 12   13            State               Madhya Pradesh
# 13   14            State                  Maharashtra
# 14   15            State                      Manipur
# 15   16            State                    Meghalaya
# ...

# %%
x=data6['States/UTs']
y=data6['Percentage of urban households with drainage facility']
plt.bar(x,y,align='edge',edgecolor='black',linewidth="2")
plt.xticks(rotation=90)
plt.xlabel("States & UTs")
plt.ylabel("Percentage of urban households with drainage facility")
# Out:
# Text(0, 0.5, 'Percentage of urban households with drainage facility')
